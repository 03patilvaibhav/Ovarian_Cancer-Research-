# %%
# import pandas as pd
import re
# from google.colab import drive
# drive.mount('/content/drive')
# df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/MAJOR_PROJECT/DATASET/result.xlsx')

# %%
status = {
    'lung': 'Not Mentioned',
    'trachea': 'Not Mentioned',
    'heart': 'Not Mentioned',
    'liver': 'Not Mentioned',
    'biliary tree': 'Not Mentioned',
    'gall bladder': 'Not Mentioned',
    'pancreas': 'Not Mentioned',
    'spleen': 'Not Mentioned',
    'kidneys': 'Not Mentioned',
    'adrenals': 'Not Mentioned',
    'GI tract': 'Not Mentioned',
    'Urinary bladder': 'Not Mentioned',
    'Uterus': 'Not Mentioned',
    'right adnexa': 'Not Mentioned',
    'bones': 'Not Mentioned',
    'Right ovary': 'Not Mentioned',
    'left ovary': 'Not Mentioned'
}

# %%
def organ_status(texts):

     for text in texts:
        for organ in status.keys():
         if re.search(r'\b' + organ + r'\b', text, re.IGNORECASE):
              re.search(r_status[organ] == 'Abnormal' if re.search(r'abnormal|lesion is seen|cystic|not seen', text, re.IGNORECASE) else 'Normal'
# Out:
#   File "<ipython-input-6-7bca46935ae2>", line 6
#     re.search(r_status[organ] == 'Abnormal' if re.search(r'abnormal|lesion is seen|cystic|not seen', text, re.IGNORECASE) else 'Normal'
#                                                                                                                                        ^
# SyntaxError: incomplete input

# %%
texts = [['Multiple (>20) bilateral lung metastases present, largest measuring 3x3cm in right upper lobe. Bilateral pleural spaces are clear.', 'Trachea and main stem bronchi are normal.', 'Heart and mediastinal great vessels are unremarkable.', 'Left ovary is mildly enlarged, measuring 4.2x2x5 cm. It however appears normal in CT morphology.', 'uterus and right ovary are not seen due to prior surgery.', 'Urinary bladder appears unremarkable.', 'liver is normal in size & shape and shows no focal or diffuse lesion.', 'no dilatation of the biliary tree.', 'gall bladder, pancreas, spleen, kidneys and adrenals appear normal.', 'GI tract appears unremarkable.', 'bones are unremarkable.']]

# %%
organ_status(texts)
print(status)
